# %% [markdown]
# # MATPLOTLIB ASSIGNMENT

# %% [markdown]
# ### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# Matplotlib is visualization library that is used to find out the pattern and insights of data.
#
# There are various charts in pyplot module
#
# 1. scatter()
# 2. bar()
#
# 3. pie()
#
# 4. barh()
#
# 5. hist()

# %% [markdown]
# ### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %% [markdown]
# ##### Note: Also add title, xlabel, and ylabel to the plot.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %% [markdown]
# scatter plot is used to check spread of the data.

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('scatter plot')
plt.show()

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function. Use the following data:

# %%
#import numpy as np
#For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
import numpy as np
x1 = np.array([0, 1, 2, 3, 4, 5]);  y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5]);  y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5]);  y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5]);  y4 = np.array([200, 350, 250, 550, 450, 150])

# %%
fig,ax = plt.subplots(4)
ax[0].plot(x1,y1)
ax[1].plot(x2,y2)
ax[2].plot(x3,y3)
ax[3].plot(x4,y4)

# %% [markdown]
# ### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# Bar charts enable us to compare numerical values like integers and percentages. They use the length of each bar to represent the value of each variable.

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# Box plot - A great chart to use when showing the distribution of data points across a selected measure. These charts display ranges within variables measured. This includes the outliers, the median, the mode, and where the majority of the data points lie in the box.

# %%
plt.boxplot(box1)
plt.show()

# %%
plt.boxplot(box2)
plt.show()
